# %%
import pandas as pd
import numpy as np
import json
from glob import glob
import matplotlib.pyplot as plt

# %%
lstm_mae = pd.read_csv("./best_models/lstm/run-17-04-2023_231059_tensorboard-tag-Training MAE per Epoch.csv")
cnn_lstm_mae = pd.read_csv("./best_models/cnn-lstm/run-17-04-2023_190141_tensorboard-tag-Training MAE per Epoch.csv")
transformer_mae = pd.read_csv("./best_models/transformer/run-17-04-2023_214336-tag-Training MAE per Epoch.csv")
cnn_transformer_mae = pd.read_csv("./best_models/cnn-transformer/run-17-04-2023_160328-tag-Training MAE per Epoch.csv")

lstm_mse = pd.read_csv("./best_models/lstm/run-17-04-2023_231059_tensorboard-tag-Training MSE per Epoch.csv")
cnn_lstm_mse = pd.read_csv("./best_models/cnn-lstm/run-17-04-2023_190141_tensorboard-tag-Training MSE per Epoch.csv")
transformer_mse = pd.read_csv("./best_models/transformer/run-17-04-2023_214336-tag-Training MSE per Epoch.csv")
cnn_transformer_mse = pd.read_csv("./best_models/cnn-transformer/run-17-04-2023_160328-tag-Training MSE per Epoch.csv")


val_lstm_mae = pd.read_csv("./best_models/lstm/run-17-04-2023_231059_tensorboard-tag-Validation MAE per Epoch.csv")
val_cnn_lstm_mae = pd.read_csv("./best_models/cnn-lstm/run-17-04-2023_190141_tensorboard-tag-Validation MAE per Epoch.csv")
val_transformer_mae = pd.read_csv("./best_models/transformer/run-17-04-2023_214336-tag-Validation MAE per Epoch.csv")
val_cnn_transformer_mae = pd.read_csv("./best_models/cnn-transformer/run-17-04-2023_160328-tag-Validation MAE per Epoch.csv")

val_lstm_mse = pd.read_csv("./best_models/lstm/run-17-04-2023_231059_tensorboard-tag-Validation MSE per Epoch.csv")
val_cnn_lstm_mse = pd.read_csv("./best_models/cnn-lstm/run-17-04-2023_190141_tensorboard-tag-Validation MSE per Epoch.csv")
val_transformer_mse = pd.read_csv("./best_models/transformer/run-17-04-2023_214336-tag-Validation MSE per Epoch.csv")
val_cnn_transformer_mse = pd.read_csv("./best_models/cnn-transformer/run-17-04-2023_160328-tag-Validation MSE per Epoch.csv")

# %%
print("MAE")
print(f"\t LSTM: {round(val_lstm_mae['Value'].min(), 5)}")
print(f"\t CNN-LSTM: {round(val_cnn_lstm_mae['Value'].min(), 5)}")
print(f"\t Transformer: {round(val_transformer_mae['Value'].min(), 5)}")
print(f"\t CNN-Transformer: {round(val_cnn_transformer_mae['Value'].min(), 5)}")
print("MSE")
print(f"\t LSTM: {round(val_lstm_mse['Value'].min(), 6)}")
print(f"\t CNN-LSTM: {round(val_cnn_lstm_mse['Value'].min(), 6)}")
print(f"\t Transformer: {round(val_transformer_mse['Value'].min(), 6)}")
print(f"\t CNN-Transformer: {round(val_cnn_transformer_mse['Value'].min(), 6)}")
# Out:
# MAE
# 	 LSTM: 0.020315
# 	 CNN-LSTM: 0.043997
# 	 Transformer: 0.029612
# 	 CNN-Transformer: 0.023984
# MSE
# 	 LSTM: 0.001222
# 	 CNN-LSTM: 0.004254
# 	 Transformer: 0.001743
# 	 CNN-Transformer: 0.001234

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MAE loss")
ax.set_xlabel("Epoch")


ax.plot(lstm_mae['Step'], lstm_mae['Value'], label="LSTM")
ax.plot(cnn_lstm_mae['Step'], cnn_lstm_mae['Value'], label="CNN-LSTM")
ax.plot(transformer_mae['Step'], transformer_mae['Value'], label="Transformer")
ax.plot(cnn_transformer_mae['Step'], cnn_transformer_mae['Value'], label="CNN-Transformer")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("Training MAE per Epoch")

plt.show()

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MSE loss")
ax.set_xlabel("Epoch")


ax.plot(lstm_mse['Step'], lstm_mse['Value'], label="LSTM")
ax.plot(cnn_lstm_mse['Step'], cnn_lstm_mse['Value'], label="CNN-LSTM")
ax.plot(transformer_mse['Step'], transformer_mse['Value'], label="Transformer")
ax.plot(cnn_transformer_mse['Step'], cnn_transformer_mse['Value'], label="CNN-Transformer")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("Training MSE per Epoch")

plt.show()

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MAE loss")
ax.set_xlabel("Epoch")


ax.plot(val_lstm_mae['Step'], val_lstm_mae['Value'], label="LSTM")
ax.plot(val_cnn_lstm_mae['Step'], val_cnn_lstm_mae['Value'], label="CNN-LSTM")
ax.plot(val_transformer_mae['Step'], val_transformer_mae['Value'], label="Transformer")
ax.plot(val_cnn_transformer_mae['Step'], val_cnn_transformer_mae['Value'], label="CNN-Transformer")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("Validation MAE per Epoch")

plt.show()

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MSE loss")
ax.set_xlabel("Epoch")


ax.plot(val_lstm_mse['Step'], val_lstm_mse['Value'], label="LSTM")
ax.plot(val_cnn_lstm_mse['Step'], val_cnn_lstm_mse['Value'], label="CNN-LSTM")
ax.plot(val_transformer_mse['Step'], val_transformer_mse['Value'], label="Transformer")
ax.plot(val_cnn_transformer_mse['Step'], val_cnn_transformer_mse['Value'], label="CNN-Transformer")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("Validation MSE per Epoch")

plt.show()

# %% [markdown]
# # Cross Validation

# %%
import pandas as pd
import numpy as np
import json
from glob import glob
import matplotlib.pyplot as plt

# %% [markdown]
# ## LSTM

# %%
lstm_mae_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S6-5-31_18-04-2023_004940_tensorboard-tag-Validation MAE per Epoch.csv")
lstm_mae_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S7-5-32_18-04-2023_010715_tensorboard-tag-Validation MAE per Epoch.csv")
lstm_mae_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S8-5-33_18-04-2023_012154_tensorboard-tag-Validation MAE per Epoch.csv")
lstm_mae_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S9-5-34_18-04-2023_013541_tensorboard-tag-Validation MAE per Epoch.csv")
lstm_mae_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S10-5-35_18-04-2023_014936_tensorboard-tag-Validation MAE per Epoch.csv")

lstm_mse_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S6-5-31_18-04-2023_004940_tensorboard-tag-Validation MSE per Epoch.csv")
lstm_mse_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S7-5-32_18-04-2023_010715_tensorboard-tag-Validation MSE per Epoch.csv")
lstm_mse_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S8-5-33_18-04-2023_012154_tensorboard-tag-Validation MSE per Epoch.csv")
lstm_mse_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S9-5-34_18-04-2023_013541_tensorboard-tag-Validation MSE per Epoch.csv")
lstm_mse_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/LSTM/run-LSTM_S10-5-35_18-04-2023_014936_tensorboard-tag-Validation MSE per Epoch.csv")

# %%
lstm_avg_mae = np.mean([lstm_mae_1['Value'].min(), lstm_mae_2['Value'].min(), lstm_mae_3['Value'].min(), lstm_mae_4['Value'].min(),lstm_mae_5['Value'].min()])
print(f'LSTM average MAE from cross-val: {lstm_avg_mae}')

lstm_avg_mse = np.mean([lstm_mse_1['Value'].min(), lstm_mse_2['Value'].min(), lstm_mse_3['Value'].min(), lstm_mse_4['Value'].min(),lstm_mse_5['Value'].min()])
print(f'LSTM average from cross-val: {lstm_avg_mse}')
# Out:
# LSTM average MAE from cross-val: 0.022417190670967056
# LSTM average from cross-val: 0.0014319191803223799

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MAE loss")
ax.set_xlabel("Epoch")


ax.plot(lstm_mae_1['Step'], lstm_mae_1['Value'], label="LSTM Cross-Val 1")
ax.plot(lstm_mae_2['Step'], lstm_mae_2['Value'], label="LSTM Cross-Val 2")
ax.plot(lstm_mae_3['Step'], lstm_mae_3['Value'], label="LSTM Cross-Val 3")
ax.plot(lstm_mae_4['Step'], lstm_mae_4['Value'], label="LSTM Cross-Val 4")
ax.plot(lstm_mae_5['Step'], lstm_mae_5['Value'], label="LSTM Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("LSTM Cross-Validation MAE")

plt.show()

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MSE loss")
ax.set_xlabel("Epoch")


ax.plot(lstm_mse_1['Step'], lstm_mse_1['Value'], label="LSTM Cross-Val 1")
ax.plot(lstm_mse_2['Step'], lstm_mse_2['Value'], label="LSTM Cross-Val 2")
ax.plot(lstm_mse_3['Step'], lstm_mse_3['Value'], label="LSTM Cross-Val 3")
ax.plot(lstm_mse_4['Step'], lstm_mse_4['Value'], label="LSTM Cross-Val 4")
ax.plot(lstm_mse_5['Step'], lstm_mse_5['Value'], label="LSTM Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("LSTM Cross-Validation MSE")

plt.show()

# %% [markdown]
# ## CNN-LSTM

# %%
cnnlstm_mae_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S6-5-31_18-04-2023_024520_tensorboard-tag-Validation MAE per Epoch.csv")
cnnlstm_mae_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S7-5-32_18-04-2023_023300_tensorboard-tag-Validation MAE per Epoch.csv")
cnnlstm_mae_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S8-5-33_18-04-2023_022328_tensorboard-tag-Validation MAE per Epoch.csv")
cnnlstm_mae_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S9-5-34_18-04-2023_020913_tensorboard-tag-Validation MAE per Epoch.csv")
cnnlstm_mae_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S10-5-35_18-04-2023_015910_tensorboard-tag-Validation MAE per Epoch.csv")

cnnlstm_mse_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S6-5-31_18-04-2023_024520_tensorboard-tag-Validation MSE per Epoch.csv")
cnnlstm_mse_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S7-5-32_18-04-2023_023300_tensorboard-tag-Validation MSE per Epoch.csv")
cnnlstm_mse_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S8-5-33_18-04-2023_022328_tensorboard-tag-Validation MSE per Epoch.csv")
cnnlstm_mse_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S9-5-34_18-04-2023_020913_tensorboard-tag-Validation MSE per Epoch.csv")
cnnlstm_mse_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/CNN-LSTM/run-CNN-LSTM_S10-5-35_18-04-2023_015910_tensorboard-tag-Validation MSE per Epoch.csv")

# %%
cnnlstm_avg_mae = np.mean([cnnlstm_mae_1['Value'].min(), cnnlstm_mae_2['Value'].min(), cnnlstm_mae_3['Value'].min(), cnnlstm_mae_4['Value'].min(),cnnlstm_mae_5['Value'].min()])
print(f'CNN-LSTM average MAE from cross-val: {cnnlstm_avg_mae}')

cnnlstm_avg_mse = np.mean([cnnlstm_mse_1['Value'].min(), cnnlstm_mse_2['Value'].min(), cnnlstm_mse_3['Value'].min(), cnnlstm_mse_4['Value'].min(),cnnlstm_mse_5['Value'].min()])
print(f'CNN-LSTM average from cross-val: {cnnlstm_avg_mse}')
# Out:
# CNN-LSTM average MAE from cross-val: 0.016004835255444
# CNN-LSTM average from cross-val: 0.0007368313032201799

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MAE loss")
ax.set_xlabel("Epoch")


ax.plot(cnnlstm_mae_1['Step'], cnnlstm_mae_1['Value'], label="CNN-LSTM Cross-Val 1")
ax.plot(cnnlstm_mae_2['Step'], cnnlstm_mae_2['Value'], label="CNN-LSTM Cross-Val 2")
ax.plot(cnnlstm_mae_3['Step'], cnnlstm_mae_3['Value'], label="CNN-LSTM Cross-Val 3")
ax.plot(cnnlstm_mae_4['Step'], cnnlstm_mae_4['Value'], label="CNN-LSTM Cross-Val 4")
ax.plot(cnnlstm_mae_5['Step'], cnnlstm_mae_5['Value'], label="CNN-LSTM Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("CNN-LSTM Cross-Validation MAE")

plt.show()

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MSE loss")
ax.set_xlabel("Epoch")


ax.plot(cnnlstm_mse_1['Step'], cnnlstm_mse_1['Value'], label="CNN-LSTM Cross-Val 1")
ax.plot(cnnlstm_mse_2['Step'], cnnlstm_mse_2['Value'], label="CNN-LSTM Cross-Val 2")
ax.plot(cnnlstm_mse_3['Step'], cnnlstm_mse_3['Value'], label="CNN-LSTM Cross-Val 3")
ax.plot(cnnlstm_mse_4['Step'], cnnlstm_mse_4['Value'], label="CNN-LSTM Cross-Val 4")
ax.plot(cnnlstm_mse_5['Step'], cnnlstm_mse_5['Value'], label="CNN-LSTM Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("CNN-LSTM Cross-Validation MSE")

plt.show()

# %% [markdown]
# ## Transformer

# %%
transformer_mae_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S6-5-31_18-04-2023_021109_tensorboard-tag-Validation MAE per Epoch.csv")
transformer_mae_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S7-5-32_18-04-2023_025329_tensorboard-tag-Validation MAE per Epoch.csv")
transformer_mae_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S8-5-33_18-04-2023_025809_tensorboard-tag-Validation MAE per Epoch.csv")
transformer_mae_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S9-5-34_18-04-2023_030547_tensorboard-tag-Validation MAE per Epoch.csv")
transformer_mae_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S10-5-35_18-04-2023_031136_tensorboard-tag-Validation MAE per Epoch.csv")

transformer_mse_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S6-5-31_18-04-2023_021109_tensorboard-tag-Validation MSE per Epoch.csv")
transformer_mse_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S7-5-32_18-04-2023_025329_tensorboard-tag-Validation MSE per Epoch.csv")
transformer_mse_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S8-5-33_18-04-2023_025809_tensorboard-tag-Validation MSE per Epoch.csv")
transformer_mse_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S9-5-34_18-04-2023_030547_tensorboard-tag-Validation MSE per Epoch.csv")
transformer_mse_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S10-5-35_18-04-2023_031136_tensorboard-tag-Validation MSE per Epoch.csv")

# %%
transformer_avg_mae = np.mean([transformer_mae_1['Value'].min(), transformer_mae_2['Value'].min(), transformer_mae_3['Value'].min(), transformer_mae_4['Value'].min(),transformer_mae_5['Value'].min()])
print(f'Transformer average MAE from cross-val: {transformer_avg_mae}')

transformer_avg_mse = np.mean([transformer_mse_1['Value'].min(), transformer_mse_2['Value'].min(), transformer_mse_3['Value'].min(), transformer_mse_4['Value'].min(),transformer_mse_5['Value'].min()])
print(f'Transformer average from cross-val: {transformer_avg_mse}')
# Out:
# Transformer average MAE from cross-val: 0.025319050997495617
# Transformer average from cross-val: 0.00129452813416716

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MAE loss")
ax.set_xlabel("Epoch")


ax.plot(transformer_mae_1['Step'], transformer_mae_1['Value'], label="Transformer Cross-Val 1")
ax.plot(transformer_mae_2['Step'], transformer_mae_2['Value'], label="Transformer Cross-Val 2")
ax.plot(transformer_mae_3['Step'], transformer_mae_3['Value'], label="Transformer Cross-Val 3")
ax.plot(transformer_mae_4['Step'], transformer_mae_4['Value'], label="Transformer Cross-Val 4")
ax.plot(transformer_mae_5['Step'], transformer_mae_5['Value'], label="Transformer Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("Transformer Cross-Validation ME")

plt.show()

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MSE loss")
ax.set_xlabel("Epoch")


ax.plot(transformer_mse_1['Step'], transformer_mse_1['Value'], label="Transformer Cross-Val 1")
ax.plot(transformer_mse_2['Step'], transformer_mse_2['Value'], label="Transformer Cross-Val 2")
ax.plot(transformer_mse_3['Step'], transformer_mse_3['Value'], label="Transformer Cross-Val 3")
ax.plot(transformer_mse_4['Step'], transformer_mse_4['Value'], label="Transformer Cross-Val 4")
ax.plot(transformer_mse_5['Step'], transformer_mse_5['Value'], label="Transformer Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("Transformer Cross-Validation MSE")

plt.show()

# %% [markdown]
# ## CNN-Transformer

# %%
cnntransformer_mse_1 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S6-5-31_18-04-2023_021109_tensorboard-tag-Validation MAE per Epoch.csv")
cnntransformer_mse_2 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S7-5-32_18-04-2023_025329_tensorboard-tag-Validation MAE per Epoch.csv")
cnntransformer_mse_3 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S8-5-33_18-04-2023_025809_tensorboard-tag-Validation MAE per Epoch.csv")
cnntransformer_mse_4 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S9-5-34_18-04-2023_030547_tensorboard-tag-Validation MAE per Epoch.csv")
cnntransformer_mse_5 = pd.read_csv("/root/jonathan/syde770-project/outputs/cross-val/Transformer/run-Transformer_S10-5-35_18-04-2023_031136_tensorboard-tag-Validation MAE per Epoch.csv")

# %%
cnntransformer_avg_mae = np.mean([cnntransformer_mae_1['Value'].min(), cnntransformer_mae_2['Value'].min(), cnntransformer_mae_3['Value'].min(), cnntransformer_mae_4['Value'].min(),cnntransformer_mae_5['Value'].min()])
print(f'CNN-Transformer average MAE from cross-val: {cnntransformer_avg_mae}')

cnntransformer_avg_mse = np.mean([cnntransformer_mse_1['Value'].min(), cnntransformer_mse_2['Value'].min(), cnntransformer_mse_3['Value'].min(), cnntransformer_mse_4['Value'].min(),cnntransformer_mse_5['Value'].min()])
print(f'CNN-Transformer average from cross-val: {cnntransformer_avg_mse}')

# %%
fig, ax = plt.subplots()

ax.set_ylabel("MAE loss")
ax.set_xlabel("Epoch")


ax.plot(cnntransformer_mse_1['Step'], cnntransformer_mse_1['Value'], label="CNN-Transformer Cross-Val 1")
ax.plot(cnntransformer_mse_2['Step'], cnntransformer_mse_2['Value'], label="CNN-Transformer Cross-Val 2")
ax.plot(cnntransformer_mse_3['Step'], cnntransformer_mse_3['Value'], label="CNN-Transformer Cross-Val 3")
ax.plot(cnntransformer_sae_4['Step'], cnntransformer_mse_4['Value'], label="CNN-Transformer Cross-Val 4")
ax.plot(cnntransformer_mse_5['Step'], cnntransformer_mse_5['Value'], label="CNN-Transformer Cross-Val 5")

plt.legend()
plt.grid('on')
plt.tight_layout()
plt.title("CNN-Transformer Cross-Validation MsE")

plt.show()
